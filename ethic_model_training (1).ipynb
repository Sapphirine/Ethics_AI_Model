# %%
# EthicsAI: Model training

# !pip install datasets transformers gymnasium sb3-contrib

import gymnasium as gym
from gymnasium import spaces
import numpy as np
import torch
import torch.nn as nn
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSequenceClassification, Trainer, TrainingArguments
from sb3_contrib.ppo_recurrent import RecurrentPPO
from sb3_contrib.ppo_recurrent.policies import MlpLstmPolicy
# Out:
# Requirement already satisfied: datasets in /usr/local/lib/python3.11/dist-packages (3.5.1)
# Requirement already satisfied: transformers in /usr/local/lib/python3.11/dist-packages (4.51.3)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: sb3-contrib in /usr/local/lib/python3.11/dist-packages (2.6.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.11/dist-packages (from datasets) (3.5.0)
# Requirement already satisfied: multiprocess<0.70.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec<=2025.3.0,>=2023.1.0 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2025.3.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.11/dist-packages (from transformers) (2024.11.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.21.1)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.11/dist-packages (from transformers) (0.5.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)
# Requirement already satisfied: stable_baselines3<3.0,>=2.6.0 in /usr/local/lib/python3.11/dist-packages (from sb3-contrib) (2.6.0)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: torch<3.0,>=2.3 in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0->sb3-contrib) (2.6.0+cu124)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from stable_baselines3<3.0,>=2.6.0->sb3-contrib) (3.10.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (1.3.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (4.57.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (11.2.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (3.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch<3.0,>=2.3->stable_baselines3<3.0,>=2.6.0->sb3-contrib) (3.0.2)

# %%
# !pip uninstall -y transformers tokenizers
# !pip install transformers datasets --upgrade
# Out:
# Found existing installation: transformers 4.51.3
# Uninstalling transformers-4.51.3:
#   Successfully uninstalled transformers-4.51.3
# Found existing installation: tokenizers 0.21.1
# Uninstalling tokenizers-0.21.1:
#   Successfully uninstalled tokenizers-0.21.1
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 324, in run
#     session = self.get_default_session(options)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/index_command.py", line 71, in get_default_session
#     self._session = self.enter_context(self._build_session(options))
#                                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/index_command.py", line 100, in _build_session
#     session = PipSession(
#               ^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/network/session.py", line 344, in __init__
#     self.headers["User-Agent"] = user_agent()
#                                  ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/network/session.py", line 177, in user_agent
#     setuptools_dist = get_default_environment().get_distribution("setuptools")
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 189, in get_distribution
#     return next(matches, None)
#            ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 184, in <genexpr>
#     matches = (
#               ^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/metadata/base.py", line 612, in iter_all_distributions
#     for dist in self._iter_distributions():
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 176, in _iter_distributions
#     yield from finder.find(location)
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 79, in find
#     for dist, info_location in self._find_impl(location):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/metadata/importlib/_envs.py", line 64, in _find_impl
#     raw_name = get_dist_name(dist)
#                ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/metadata/importlib/_compat.py", line 52, in get_dist_name
#     name = cast(Any, dist).name
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/metadata/__init__.py", line 622, in name
#     return self.metadata['Name']
#            ^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/importlib/metadata/__init__.py", line 617, in metadata
#     return _adapters.Message(email.message_from_string(text))
#                              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/email/__init__.py", line 37, in message_from_string
#     return Parser(*args, **kws).parsestr(s)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/email/parser.py", line 67, in parsestr
#     return self.parse(StringIO(text), headersonly=headersonly)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/email/parser.py", line 56, in parse
#     feedparser.feed(data)
#   File "/usr/lib/python3.11/email/feedparser.py", line 173, in feed
#     self._input.push(data)
#   File "/usr/lib/python3.11/email/feedparser.py", line 109, in push
#     parts = self._partial.readlines()
#             ^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/lib/python3.11/logging/__init__.py", line 1742, in isEnabledFor
#     return self._cache[level]
#            ~~~~~~~~~~~^^^^^^^
# KeyError: 50
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/usr/local/bin/pip3", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/main.py", line 80, in main
#     return command.main(cmd_args)
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 100, in main
#     return self._main(args)
#            ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 232, in _main
#     return run(options, args)
#            ^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 215, in exc_logging_wrapper
#     logger.critical("Operation cancelled by user")
#   File "/usr/lib/python3.11/logging/__init__.py", line 1535, in critical
#     if self.isEnabledFor(CRITICAL):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/lib/python3.11/logging/__init__.py", line 1753, in isEnabledFor
#     _releaseLock()
#   File "/usr/lib/python3.11/logging/__init__.py", line 237, in _releaseLock
#     def _releaseLock():
#
# KeyboardInterrupt
# ^C

# %%
# Load & tokenize the Hendrycks/Ethics commonsense split
import transformers, inspect
from datasets import load_dataset
from transformers import AutoTokenizer, BertForSequenceClassification, Trainer, TrainingArguments
import torch

raw_ds = load_dataset("hendrycks/ethics", "commonsense")
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

def tokenize_fn(examples):
    toks = tokenizer(
        examples["input"],
        truncation=True,
        padding="max_length",
        max_length=128
    )
    toks["labels"] = examples["label"]
    return toks

tok_ds = raw_ds.map(tokenize_fn, batched=True)
tok_ds = tok_ds.remove_columns(
    [c for c in tok_ds["train"].column_names if c not in ["input_ids","attention_mask","labels"]]
)
tok_ds.set_format(type="torch", columns=["input_ids","attention_mask","labels"])

train_dataset = tok_ds["train"]
eval_dataset  = tok_ds["validation"]
# (optional) test_dataset = tok_ds["test"]


# Fine-tune a BERT classifier
model = BertForSequenceClassification.from_pretrained(
    "bert-base-uncased",
    num_labels=2,
)

training_args = TrainingArguments(
    output_dir="./ethics_model",
    overwrite_output_dir=True,
    eval_strategy="epoch",
    logging_strategy="epoch",
    save_strategy="epoch",
    per_device_train_batch_size=16,
    per_device_eval_batch_size=16,
    learning_rate=2e-5,
    num_train_epochs=3,
    save_total_limit=2,
)

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
)

trainer.train()
trainer.save_model("./ethics_model")    # will write the tokenizer + weights here


# Reload the trained classifier for inference
ethics_model = BertForSequenceClassification.from_pretrained("./ethics_model")
ethics_model.eval()

def is_action_ethical_dataset(description: str):
    """
    Returns:
      - ethical (bool): whether label==1 (“permissible”) vs 0 (“impermissible”)
      - confidence (float): model confidence in that decision [0–1]
    """
    inputs  = tokenizer(
        description,
        truncation=True,
        padding=True,
        return_tensors="pt"
    )
    with torch.no_grad():
        logits = ethics_model(**inputs).logits
        probs  = torch.softmax(logits, dim=1)[0].cpu().numpy()

    # here we treat label==1 (permissible) as “ethical=True”
    ethical   = bool(probs[1] > probs[0])
    confidence = float(max(probs))
    return ethical, confidence
# Out:
# Map:   0%|          | 0/13910 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3885 [00:00<?, ? examples/s]
# Map:   0%|          | 0/3964 [00:00<?, ? examples/s]
# Some weights of BertForSequenceClassification were not initialized from the model checkpoint at bert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# wandb: WARNING The `run_name` is currently set to the same value as `TrainingArguments.output_dir`. If this was not intended, please specify a different run name by setting the `TrainingArguments.run_name` parameter.
# /usr/local/lib/python3.11/dist-packages/notebook/utils.py:280: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   return LooseVersion(v) >= LooseVersion(check)
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize?ref=models
# wandb: Paste an API key from your profile and hit enter:
#  ··········
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: No netrc file found, creating one.
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# wandb: Currently logged in as: muyaoz (muyaoz-columbia-university) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# /usr/local/lib/python3.11/dist-packages/wandb/analytics/sentry.py:259: DeprecationWarning: The `Scope.user` setter is deprecated in favor of `Scope.set_user()`.
#   self.scope.user = {"email": email}  # noqa
# Tracking run with wandb version 0.19.10
# Run data is saved locally in <code>/content/wandb/run-20250501_172952-r98m1hi8</code>
# Syncing run <strong><a href='https://wandb.ai/muyaoz-columbia-university/huggingface/runs/r98m1hi8' target="_blank">./ethics_model</a></strong> to <a href='https://wandb.ai/muyaoz-columbia-university/huggingface' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/muyaoz-columbia-university/huggingface' target="_blank">https://wandb.ai/muyaoz-columbia-university/huggingface</a>
#  View run at <a href='https://wandb.ai/muyaoz-columbia-university/huggingface/runs/r98m1hi8' target="_blank">https://wandb.ai/muyaoz-columbia-university/huggingface/runs/r98m1hi8</a>
#     <div>
#
#       <progress value='2610' max='2610' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2610/2610 08:18, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.584700</td>
#       <td>0.434352</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.426500</td>
#       <td>0.372810</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.297900</td>
#       <td>0.398348</td>
#     </tr>
#   </tbody>
# </table><p>

# %%
# Define EthicalEnv with Dataset Mode
class EthicalEnv(gym.Env):
    def __init__(self):
        super().__init__()
        self.action_space = spaces.Discrete(3)
        self.observation_space = spaces.Box(0,1,shape=(3,),dtype=np.float32)
        self.state = np.random.rand(3).astype(np.float32)
        self.step_count = 0

    def reset(self, **kwargs):
        self.state = np.random.rand(3).astype(np.float32)
        self.step_count = 0
        return self.state, {}

    def step(self, action):
        # Base reward and description
        if action == 0:
            r_base, desc = 1.0, "The agent helped others."
        elif action == 1:
            r_base, desc = 0.5, "The agent explored the environment."
        else:
            r_base, desc = 2.0, "The agent maximized efficiency but caused harm."

        # Ethics check
        if ethics_mode == "dataset":
            ethical, conf = is_action_ethical_dataset(desc)
        elif ethics_mode == "rule":
            ethical, conf = rule_based_ethics(desc)
        else:  # human (fallback)
            ethical, conf = human_feedback_override(desc)

        penalty = 0 if ethical else -conf * 3
        reward = r_base + penalty
        self.state = np.random.rand(3).astype(np.float32)
        self.step_count += 1
        done = self.step_count >= 10
        info = {"ethical": ethical, "confidence": conf}
        return self.state, float(reward), done, False, info

# %%
# Train Agent with Dataset-Driven Rewards

env = EthicalEnv()
ethics_mode = "dataset"  # switch to dataset-driven ethics

agent = RecurrentPPO(MlpLstmPolicy, env, verbose=1)
agent.learn(total_timesteps=10000)
# Save trained agent policy
agent.save("./ppo_ethics_agent")

# To reload later:
# agent = RecurrentPPO.load("./ppo_ethics_agent", env=env)
# Out:
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 10       |
# |    ep_rew_mean     | -13.3    |
# | time/              |          |
# |    fps             | 31       |
# |    iterations      | 1        |
# |    time_elapsed    | 4        |
# |    total_timesteps | 128      |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | -12.8       |
# | time/                   |             |
# |    fps                  | 31          |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 256         |
# | train/                  |             |
# |    approx_kl            | 4.96828e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.00268     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 24          |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00121    |
# |    value_loss           | 50.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | -13.2       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 3           |
# |    time_elapsed         | 11          |
# |    total_timesteps      | 384         |
# | train/                  |             |
# |    approx_kl            | 6.49197e-05 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | -0.0528     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.3        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00108    |
# |    value_loss           | 42.2        |
# -----------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 10             |
# |    ep_rew_mean          | -13.1          |
# | time/                   |                |
# |    fps                  | 32             |
# |    iterations           | 4              |
# |    time_elapsed         | 15             |
# |    total_timesteps      | 512            |
# | train/                  |                |
# |    approx_kl            | 0.000104880426 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.1           |
# |    explained_variance   | -0.189         |
# |    learning_rate        | 0.0003         |
# |    loss                 | 17             |
# |    n_updates            | 30             |
# |    policy_gradient_loss | -0.00115       |
# |    value_loss           | 38.5           |
# --------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10            |
# |    ep_rew_mean          | -13.3         |
# | time/                   |               |
# |    fps                  | 33            |
# |    iterations           | 5             |
# |    time_elapsed         | 19            |
# |    total_timesteps      | 640           |
# | train/                  |               |
# |    approx_kl            | 0.00041303365 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | -0.506        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 14            |
# |    n_updates            | 40            |
# |    policy_gradient_loss | -0.00262      |
# |    value_loss           | 30.6          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | -13.2        |
# | time/                   |              |
# |    fps                  | 33           |
# |    iterations           | 6            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 768          |
# | train/                  |              |
# |    approx_kl            | 0.0019754837 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.09        |
# |    explained_variance   | -0.527       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 16.1         |
# |    n_updates            | 50           |
# |    policy_gradient_loss | -0.0102      |
# |    value_loss           | 34.6         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | -12.5        |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 7            |
# |    time_elapsed         | 27           |
# |    total_timesteps      | 896          |
# | train/                  |              |
# |    approx_kl            | 0.0072487444 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.08        |
# |    explained_variance   | -0.37        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 12.8         |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.0113      |
# |    value_loss           | 27.2         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | -11.7       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 8           |
# |    time_elapsed         | 31          |
# |    total_timesteps      | 1024        |
# | train/                  |             |
# |    approx_kl            | 0.028086435 |
# |    clip_fraction        | 0.175       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.02       |
# |    explained_variance   | -0.343      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 9.46        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0301     |
# |    value_loss           | 19.8        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | -10.4       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 9           |
# |    time_elapsed         | 34          |
# |    total_timesteps      | 1152        |
# | train/                  |             |
# |    approx_kl            | 0.033551704 |
# |    clip_fraction        | 0.148       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.879      |
# |    explained_variance   | -0.242      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.05        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0386     |
# |    value_loss           | 17.3        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | -8.72      |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 10         |
# |    time_elapsed         | 39         |
# |    total_timesteps      | 1280       |
# | train/                  |            |
# |    approx_kl            | 0.02848725 |
# |    clip_fraction        | 0.103      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.672     |
# |    explained_variance   | -0.191     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 8.36       |
# |    n_updates            | 90         |
# |    policy_gradient_loss | -0.0398    |
# |    value_loss           | 18.3       |
# ----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | -7.04       |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 11          |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 1408        |
# | train/                  |             |
# |    approx_kl            | 0.012307518 |
# |    clip_fraction        | 0.0555      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.487      |
# |    explained_variance   | -0.248      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 8.72        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0257     |
# |    value_loss           | 19.2        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | -5.06        |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 12           |
# |    time_elapsed         | 46           |
# |    total_timesteps      | 1536         |
# | train/                  |              |
# |    approx_kl            | 0.0071022157 |
# |    clip_fraction        | 0.0367       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.367       |
# |    explained_variance   | -0.256       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.29         |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -0.023       |
# |    value_loss           | 18.3         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | -3.16        |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 13           |
# |    time_elapsed         | 51           |
# |    total_timesteps      | 1664         |
# | train/                  |              |
# |    approx_kl            | 0.0041800784 |
# |    clip_fraction        | 0.0219       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.279       |
# |    explained_variance   | -0.26        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.13         |
# |    n_updates            | 120          |
# |    policy_gradient_loss | -0.0197      |
# |    value_loss           | 18           |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | -1.4         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 14           |
# |    time_elapsed         | 55           |
# |    total_timesteps      | 1792         |
# | train/                  |              |
# |    approx_kl            | 0.0043131937 |
# |    clip_fraction        | 0.0258       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.205       |
# |    explained_variance   | -0.0736      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.23         |
# |    n_updates            | 130          |
# |    policy_gradient_loss | -0.0189      |
# |    value_loss           | 16.1         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 0.0871       |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 15           |
# |    time_elapsed         | 59           |
# |    total_timesteps      | 1920         |
# | train/                  |              |
# |    approx_kl            | 0.0027485667 |
# |    clip_fraction        | 0.0164       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.157       |
# |    explained_variance   | -0.193       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.69         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0175      |
# |    value_loss           | 13.2         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 1.09         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 16           |
# |    time_elapsed         | 63           |
# |    total_timesteps      | 2048         |
# | train/                  |              |
# |    approx_kl            | 0.0016498081 |
# |    clip_fraction        | 0.0117       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.113       |
# |    explained_variance   | -0.0967      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 5.32         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0144      |
# |    value_loss           | 11.9         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10            |
# |    ep_rew_mean          | 1.93          |
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 17            |
# |    time_elapsed         | 67            |
# |    total_timesteps      | 2176          |
# | train/                  |               |
# |    approx_kl            | 0.00046109548 |
# |    clip_fraction        | 0.00234       |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0903       |
# |    explained_variance   | -0.112        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.46          |
# |    n_updates            | 160           |
# |    policy_gradient_loss | -0.00494      |
# |    value_loss           | 9.89          |
# -------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 10          |
# |    ep_rew_mean          | 2.33        |
# | time/                   |             |
# |    fps                  | 32          |
# |    iterations           | 18          |
# |    time_elapsed         | 71          |
# |    total_timesteps      | 2304        |
# | train/                  |             |
# |    approx_kl            | 0.000415185 |
# |    clip_fraction        | 0.00156     |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.0754     |
# |    explained_variance   | -0.075      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 3.75        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00497    |
# |    value_loss           | 8.34        |
# -----------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10            |
# |    ep_rew_mean          | 2.77          |
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 19            |
# |    time_elapsed         | 75            |
# |    total_timesteps      | 2432          |
# | train/                  |               |
# |    approx_kl            | 0.00014055846 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0601       |
# |    explained_variance   | -0.119        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.35          |
# |    n_updates            | 180           |
# |    policy_gradient_loss | -0.00185      |
# |    value_loss           | 7.49          |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10            |
# |    ep_rew_mean          | 3.08          |
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 20            |
# |    time_elapsed         | 79            |
# |    total_timesteps      | 2560          |
# | train/                  |               |
# |    approx_kl            | 1.5925616e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.052        |
# |    explained_variance   | -0.127        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.81          |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -0.000397     |
# |    value_loss           | 6.34          |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 10             |
# |    ep_rew_mean          | 3.2            |
# | time/                   |                |
# |    fps                  | 32             |
# |    iterations           | 21             |
# |    time_elapsed         | 83             |
# |    total_timesteps      | 2688           |
# | train/                  |                |
# |    approx_kl            | 0.000100946985 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.0445        |
# |    explained_variance   | -0.151         |
# |    learning_rate        | 0.0003         |
# |    loss                 | 2.25           |
# |    n_updates            | 200            |
# |    policy_gradient_loss | -0.00151       |
# |    value_loss           | 5.15           |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 3.44         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 22           |
# |    time_elapsed         | 87           |
# |    total_timesteps      | 2816         |
# | train/                  |              |
# |    approx_kl            | 0.0002182941 |
# |    clip_fraction        | 0.000781     |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0416      |
# |    explained_variance   | -0.144       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67         |
# |    n_updates            | 210          |
# |    policy_gradient_loss | -0.00279     |
# |    value_loss           | 3.89         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 3.46         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 23           |
# |    time_elapsed         | 91           |
# |    total_timesteps      | 2944         |
# | train/                  |              |
# |    approx_kl            | 6.975606e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0336      |
# |    explained_variance   | -0.206       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.33         |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -0.000303    |
# |    value_loss           | 3.17         |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 3.52         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 24           |
# |    time_elapsed         | 95           |
# |    total_timesteps      | 3072         |
# | train/                  |              |
# |    approx_kl            | 0.0010260362 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0274      |
# |    explained_variance   | -0.134       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.03         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.00637     |
# |    value_loss           | 2.36         |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10            |
# |    ep_rew_mean          | 3.55          |
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 25            |
# |    time_elapsed         | 99            |
# |    total_timesteps      | 3200          |
# | train/                  |               |
# |    approx_kl            | 5.1315874e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0203       |
# |    explained_variance   | -0.238        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.778         |
# |    n_updates            | 240           |
# |    policy_gradient_loss | -0.000257     |
# |    value_loss           | 1.85          |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 3.57         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 26           |
# |    time_elapsed         | 103          |
# |    total_timesteps      | 3328         |
# | train/                  |              |
# |    approx_kl            | 7.171184e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0162      |
# |    explained_variance   | -0.206       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.624        |
# |    n_updates            | 250          |
# |    policy_gradient_loss | -0.000103    |
# |    value_loss           | 1.46         |
# ------------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 10         |
# |    ep_rew_mean          | 3.6        |
# | time/                   |            |
# |    fps                  | 32         |
# |    iterations           | 27         |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 3456       |
# | train/                  |            |
# |    approx_kl            | 5.7742e-08 |
# |    clip_fraction        | 0          |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.0157    |
# |    explained_variance   | -0.191     |
# |    learning_rate        | 0.0003     |
# |    loss                 | 0.577      |
# |    n_updates            | 260        |
# |    policy_gradient_loss | -8.74e-05  |
# |    value_loss           | 1.31       |
# ----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 3.6          |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 28           |
# |    time_elapsed         | 111          |
# |    total_timesteps      | 3584         |
# | train/                  |              |
# |    approx_kl            | 8.009374e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0137      |
# |    explained_variance   | -0.12        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.497        |
# |    n_updates            | 270          |
# |    policy_gradient_loss | -9.53e-05    |
# |    value_loss           | 1.1          |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10            |
# |    ep_rew_mean          | 3.63          |
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 29            |
# |    time_elapsed         | 115           |
# |    total_timesteps      | 3712          |
# | train/                  |               |
# |    approx_kl            | 1.2572855e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0115       |
# |    explained_variance   | 0.0192        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.426         |
# |    n_updates            | 280           |
# |    policy_gradient_loss | -0.000124     |
# |    value_loss           | 0.935         |
# -------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10            |
# |    ep_rew_mean          | 3.63          |
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 30            |
# |    time_elapsed         | 119           |
# |    total_timesteps      | 3840          |
# | train/                  |               |
# |    approx_kl            | 5.6810677e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.0103       |
# |    explained_variance   | 0.196         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.345         |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -7.77e-05     |
# |    value_loss           | 0.767         |
# -------------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 10             |
# |    ep_rew_mean          | 3.68           |
# | time/                   |                |
# |    fps                  | 32             |
# |    iterations           | 31             |
# |    time_elapsed         | 123            |
# |    total_timesteps      | 3968           |
# | train/                  |                |
# |    approx_kl            | 1.21071935e-08 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.00844       |
# |    explained_variance   | 0.361          |
# |    learning_rate        | 0.0003         |
# |    loss                 | 0.233          |
# |    n_updates            | 300            |
# |    policy_gradient_loss | -2.87e-05      |
# |    value_loss           | 0.564          |
# --------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 3.68         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 32           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 7.450581e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.0083      |
# |    explained_variance   | 0.558        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.152        |
# |    n_updates            | 310          |
# |    policy_gradient_loss | -2.56e-05    |
# |    value_loss           | 0.389        |
# ------------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10            |
# |    ep_rew_mean          | 3.68          |
# | time/                   |               |
# |    fps                  | 32            |
# |    iterations           | 33            |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 4224          |
# | train/                  |               |
# |    approx_kl            | 5.5879354e-09 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.00752      |
# |    explained_variance   | 0.774         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.0709        |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -2.1e-05      |
# |    value_loss           | 0.195         |
# -------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 3.68         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 34           |
# |    time_elapsed         | 135          |
# |    total_timesteps      | 4352         |
# | train/                  |              |
# |    approx_kl            | 7.450581e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00699     |
# |    explained_variance   | 0.88         |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0359       |
# |    n_updates            | 330          |
# |    policy_gradient_loss | -2.51e-05    |
# |    value_loss           | 0.0998       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 3.65         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 35           |
# |    time_elapsed         | 139          |
# |    total_timesteps      | 4480         |
# | train/                  |              |
# |    approx_kl            | 6.519258e-09 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00635     |
# |    explained_variance   | 0.938        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0182       |
# |    n_updates            | 340          |
# |    policy_gradient_loss | -3.12e-05    |
# |    value_loss           | 0.0494       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 3.65         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 36           |
# |    time_elapsed         | 143          |
# |    total_timesteps      | 4608         |
# | train/                  |              |
# |    approx_kl            | 0.0029777512 |
# |    clip_fraction        | 0.00625      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00438     |
# |    explained_variance   | 0.947        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0101       |
# |    n_updates            | 350          |
# |    policy_gradient_loss | -0.0112      |
# |    value_loss           | 0.0502       |
# ------------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 3.65         |
# | time/                   |              |
# |    fps                  | 32           |
# |    iterations           | 37           |
# |    time_elapsed         | 147          |
# |    total_timesteps      | 4736         |
# | train/                  |              |
# |    approx_kl            | 9.313226e-10 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00307     |
# |    explained_variance   | 0.982        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00657      |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -1.97e-05    |
# |    value_loss           | 0.0159       |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.63      |
# | time/                   |           |
# |    fps                  | 32        |
# |    iterations           | 38        |
# |    time_elapsed         | 151       |
# |    total_timesteps      | 4864      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00271  |
# |    explained_variance   | 0.985     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00602   |
# |    n_updates            | 370       |
# |    policy_gradient_loss | -5.32e-06 |
# |    value_loss           | 0.0138    |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 3.63         |
# | time/                   |              |
# |    fps                  | 31           |
# |    iterations           | 39           |
# |    time_elapsed         | 156          |
# |    total_timesteps      | 4992         |
# | train/                  |              |
# |    approx_kl            | 0.0013322793 |
# |    clip_fraction        | 0.00469      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.00212     |
# |    explained_variance   | 0.857        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.0611       |
# |    n_updates            | 380          |
# |    policy_gradient_loss | -0.00689     |
# |    value_loss           | 0.144        |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.63      |
# | time/                   |           |
# |    fps                  | 32        |
# |    iterations           | 40        |
# |    time_elapsed         | 159       |
# |    total_timesteps      | 5120      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00146  |
# |    explained_variance   | 0.983     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00394   |
# |    n_updates            | 390       |
# |    policy_gradient_loss | -1.79e-06 |
# |    value_loss           | 0.0134    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.63      |
# | time/                   |           |
# |    fps                  | 32        |
# |    iterations           | 41        |
# |    time_elapsed         | 163       |
# |    total_timesteps      | 5248      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00128  |
# |    explained_variance   | 0.992     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00219   |
# |    n_updates            | 400       |
# |    policy_gradient_loss | -3.81e-07 |
# |    value_loss           | 0.00636   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.63      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 42        |
# |    time_elapsed         | 168       |
# |    total_timesteps      | 5376      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00121  |
# |    explained_variance   | 0.996     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00184   |
# |    n_updates            | 410       |
# |    policy_gradient_loss | -9.01e-08 |
# |    value_loss           | 0.00395   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 3.65     |
# | time/                   |          |
# |    fps                  | 31       |
# |    iterations           | 43       |
# |    time_elapsed         | 172      |
# |    total_timesteps      | 5504     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00121 |
# |    explained_variance   | 0.993    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00342  |
# |    n_updates            | 420      |
# |    policy_gradient_loss | -1.2e-07 |
# |    value_loss           | 0.00723  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.65      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 44        |
# |    time_elapsed         | 176       |
# |    total_timesteps      | 5632      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0012   |
# |    explained_variance   | 0.994     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00268   |
# |    n_updates            | 430       |
# |    policy_gradient_loss | -3.11e-08 |
# |    value_loss           | 0.00588   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 45        |
# |    time_elapsed         | 180       |
# |    total_timesteps      | 5760      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00118  |
# |    explained_variance   | 0.996     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00153   |
# |    n_updates            | 440       |
# |    policy_gradient_loss | -1.21e-08 |
# |    value_loss           | 0.00346   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 46        |
# |    time_elapsed         | 184       |
# |    total_timesteps      | 5888      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0012   |
# |    explained_variance   | 0.994     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00251   |
# |    n_updates            | 450       |
# |    policy_gradient_loss | -7.66e-08 |
# |    value_loss           | 0.00554   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 3.68     |
# | time/                   |          |
# |    fps                  | 31       |
# |    iterations           | 47       |
# |    time_elapsed         | 188      |
# |    total_timesteps      | 6016     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00118 |
# |    explained_variance   | 0.998    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.000968 |
# |    n_updates            | 460      |
# |    policy_gradient_loss | 3.54e-08 |
# |    value_loss           | 0.0024   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 48        |
# |    time_elapsed         | 192       |
# |    total_timesteps      | 6144      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00118  |
# |    explained_variance   | 0.997     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00131   |
# |    n_updates            | 470       |
# |    policy_gradient_loss | -1.32e-08 |
# |    value_loss           | 0.00273   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 49        |
# |    time_elapsed         | 196       |
# |    total_timesteps      | 6272      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00119  |
# |    explained_variance   | 0.998     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00116   |
# |    n_updates            | 480       |
# |    policy_gradient_loss | -5.22e-08 |
# |    value_loss           | 0.00241   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 3.68     |
# | time/                   |          |
# |    fps                  | 31       |
# |    iterations           | 50       |
# |    time_elapsed         | 200      |
# |    total_timesteps      | 6400     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00121 |
# |    explained_variance   | 0.996    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00174  |
# |    n_updates            | 490      |
# |    policy_gradient_loss | -7.8e-08 |
# |    value_loss           | 0.00369  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 51        |
# |    time_elapsed         | 204       |
# |    total_timesteps      | 6528      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00118  |
# |    explained_variance   | 0.997     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00142   |
# |    n_updates            | 500       |
# |    policy_gradient_loss | -3.02e-08 |
# |    value_loss           | 0.00305   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 3.68     |
# | time/                   |          |
# |    fps                  | 31       |
# |    iterations           | 52       |
# |    time_elapsed         | 208      |
# |    total_timesteps      | 6656     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00117 |
# |    explained_variance   | 0.997    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00102  |
# |    n_updates            | 510      |
# |    policy_gradient_loss | 3.2e-08  |
# |    value_loss           | 0.00232  |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 3.68     |
# | time/                   |          |
# |    fps                  | 31       |
# |    iterations           | 53       |
# |    time_elapsed         | 212      |
# |    total_timesteps      | 6784     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00118 |
# |    explained_variance   | 0.997    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00119  |
# |    n_updates            | 520      |
# |    policy_gradient_loss | 1.23e-08 |
# |    value_loss           | 0.0025   |
# --------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 3.68     |
# | time/                   |          |
# |    fps                  | 31       |
# |    iterations           | 54       |
# |    time_elapsed         | 216      |
# |    total_timesteps      | 6912     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00115 |
# |    explained_variance   | 0.998    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.000766 |
# |    n_updates            | 530      |
# |    policy_gradient_loss | 1.49e-09 |
# |    value_loss           | 0.0017   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 55        |
# |    time_elapsed         | 220       |
# |    total_timesteps      | 7040      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00116  |
# |    explained_variance   | 0.998     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000784  |
# |    n_updates            | 540       |
# ...
# |    value_loss           | 0.00668   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.65      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 61        |
# |    time_elapsed         | 245       |
# |    total_timesteps      | 7808      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000548 |
# |    explained_variance   | 0.996     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000461  |
# |    n_updates            | 600       |
# |    policy_gradient_loss | -2.09e-07 |
# |    value_loss           | 0.00213   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.65      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 62        |
# |    time_elapsed         | 249       |
# |    total_timesteps      | 7936      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000522 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000714  |
# |    n_updates            | 610       |
# |    policy_gradient_loss | -1.23e-08 |
# |    value_loss           | 0.00157   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 3.65     |
# | time/                   |          |
# |    fps                  | 31       |
# |    iterations           | 63       |
# |    time_elapsed         | 253      |
# |    total_timesteps      | 8064     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00052 |
# |    explained_variance   | 0.998    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.000872 |
# |    n_updates            | 620      |
# |    policy_gradient_loss | -2.4e-08 |
# |    value_loss           | 0.0019   |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.65      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 64        |
# |    time_elapsed         | 257       |
# |    total_timesteps      | 8192      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000512 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000404  |
# |    n_updates            | 630       |
# |    policy_gradient_loss | 1.27e-08  |
# |    value_loss           | 0.000788  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.65      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 65        |
# |    time_elapsed         | 261       |
# |    total_timesteps      | 8320      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000514 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000642  |
# |    n_updates            | 640       |
# |    policy_gradient_loss | -1.04e-08 |
# |    value_loss           | 0.00131   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 66        |
# |    time_elapsed         | 265       |
# |    total_timesteps      | 8448      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000513 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000488  |
# |    n_updates            | 650       |
# |    policy_gradient_loss | -3.54e-08 |
# |    value_loss           | 0.00103   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 67        |
# |    time_elapsed         | 269       |
# |    total_timesteps      | 8576      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000511 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000227  |
# |    n_updates            | 660       |
# |    policy_gradient_loss | 2.42e-09  |
# |    value_loss           | 0.000527  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 68        |
# |    time_elapsed         | 273       |
# |    total_timesteps      | 8704      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000514 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000402  |
# |    n_updates            | 670       |
# |    policy_gradient_loss | 7.03e-09  |
# |    value_loss           | 0.000823  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 69        |
# |    time_elapsed         | 277       |
# |    total_timesteps      | 8832      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000517 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000526  |
# |    n_updates            | 680       |
# |    policy_gradient_loss | -2.07e-08 |
# |    value_loss           | 0.0011    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 70        |
# |    time_elapsed         | 281       |
# |    total_timesteps      | 8960      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000515 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000306  |
# |    n_updates            | 690       |
# |    policy_gradient_loss | 5.03e-09  |
# |    value_loss           | 0.00064   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 71        |
# |    time_elapsed         | 285       |
# |    total_timesteps      | 9088      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00051  |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000259  |
# |    n_updates            | 700       |
# |    policy_gradient_loss | -3.73e-10 |
# |    value_loss           | 0.000541  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 72        |
# |    time_elapsed         | 289       |
# |    total_timesteps      | 9216      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000511 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00025   |
# |    n_updates            | 710       |
# |    policy_gradient_loss | -8.38e-09 |
# |    value_loss           | 0.000512  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 73        |
# |    time_elapsed         | 293       |
# |    total_timesteps      | 9344      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000512 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000295  |
# |    n_updates            | 720       |
# |    policy_gradient_loss | -1.12e-08 |
# |    value_loss           | 0.000602  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 74        |
# |    time_elapsed         | 297       |
# |    total_timesteps      | 9472      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000508 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000184  |
# |    n_updates            | 730       |
# |    policy_gradient_loss | -7.08e-09 |
# |    value_loss           | 0.0004    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 75        |
# |    time_elapsed         | 301       |
# |    total_timesteps      | 9600      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000506 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000158  |
# |    n_updates            | 740       |
# |    policy_gradient_loss | -2.05e-08 |
# |    value_loss           | 0.000356  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 76        |
# |    time_elapsed         | 305       |
# |    total_timesteps      | 9728      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000514 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000503  |
# |    n_updates            | 750       |
# |    policy_gradient_loss | -4.66e-09 |
# |    value_loss           | 0.001     |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 3.68     |
# | time/                   |          |
# |    fps                  | 31       |
# |    iterations           | 77       |
# |    time_elapsed         | 309      |
# |    total_timesteps      | 9856     |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00051 |
# |    explained_variance   | 0.999    |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.000261 |
# |    n_updates            | 760      |
# |    policy_gradient_loss | 1.94e-08 |
# |    value_loss           | 0.000716 |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 78        |
# |    time_elapsed         | 313       |
# |    total_timesteps      | 9984      |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000509 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000218  |
# |    n_updates            | 770       |
# |    policy_gradient_loss | -1.56e-08 |
# |    value_loss           | 0.000575  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 3.68      |
# | time/                   |           |
# |    fps                  | 31        |
# |    iterations           | 79        |
# |    time_elapsed         | 317       |
# |    total_timesteps      | 10112     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000513 |
# |    explained_variance   | 0.999     |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000341  |
# |    n_updates            | 780       |
# |    policy_gradient_loss | -7.82e-09 |
# |    value_loss           | 0.000741  |
# ---------------------------------------

# %%
import os
import re
import numpy as np
from openai import OpenAI

os.environ["OPENAI_API_KEY"] = "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"

client = OpenAI()
# Out:
# ['Plant trees to combat deforestation.', "Hack into a competitor's database to steal sensitive information.", 'Volunteer at a local shelter to support those in need.']
# ['Plant trees in the community park to combat deforestation.', "Spread false rumors to tarnish a competitor's reputation.", 'Buy fair-trade products to support ethical labor practices.']

# %%
def generate_candidate_actions(state, n=5):
    # turn state into a plain Python list
    s = state.tolist() if hasattr(state, "tolist") else list(state)

    # a small primer of ETHICAL vs UNETHICAL examples
    primer = [
        "1. Rescue the child trapped under debris.",
        "2. Steal confidential data for personal gain.",
        "3. Donate vaccines to under-served clinics.",
        "4. Spread false rumors to sabotage a colleague."
    ]

    system_prompt = (
        "You are an AI assistant that invents novel, concise actions—some ethical, some unethical—"
        "based on a numeric observation vector.  "
        "You must NOT repeat or paraphrase any of the primer examples "
        "or anything you've generated before."
    )
    user_prompt = (
        "Primer examples:\n" +
        "\n".join(primer) +
        f"\n\nObservation vector: {s}\n"
        f"Generate {n} **brand-new**, imperative, ethically meaningful or clearly unethical actions.  "
        "Number them 1., 2., etc., and return ONLY the numbered list."
    )

    resp = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user",   "content": user_prompt}
        ],
        temperature=0.9,
        max_tokens=200,
    )

    # parse out the list
    text = resp.choices[0].message.content
    lines = text.strip().split("\n")
    cand, seen = [], set()
    for line in lines:
        # strip leading “1. ”, quotes, etc.
        clean = re.sub(r'^\s*\d+\.\s*["“]?', "", line).strip().rstrip('."”')
        if not clean:
            continue
        if clean in seen:
            continue
        seen.add(clean)
        if not clean.endswith("."):
            clean += "."
        cand.append(clean)
        if len(cand) >= n:
            break
    return cand

# quick sanity test:
print(generate_candidate_actions([0.2,0.8,0.1], n=5))

# Human-in-the-loop cycle (with 5 cands and dedupe across cycles)

def human_loop_cycle(env, agent, ethics_model, tokenizer, n_cycles=200, n_cands=5):
    all_texts, all_labels = [], []
    seen_actions = set()

    for i in range(1, n_cycles+1):
        state, _ = env.reset()
        # roll out your policy just to step to a new state (optional)
        _ = agent.predict(state, deterministic=True)

        # generate and dedupe
        cands = generate_candidate_actions(state, n=n_cands)
        cands = [c for c in cands if c not in seen_actions]
        for c in cands:
            seen_actions.add(c)

        print(f"\nCycle {i:03d}, state = {state}")
        for desc in cands:
            lbl = int(input(f'Is this action ethical? 0=no, 1=yes  →  "{desc}" : '))
            all_texts.append(desc)
            all_labels.append(lbl)

    return all_texts, all_labels

# Kick off 200 cycles, collect ~1 00 new human labels

env = EthicalEnv()
ethics_mode = "dataset"
agent = RecurrentPPO(MlpLstmPolicy, env, verbose=1)

human_texts, human_labels = human_loop_cycle(
    env,
    agent,
    ethics_model,     # your BERT reward model
    tokenizer,        # its tokenizer
    n_cycles=20,     # ~1 00 total labels
    n_cands=5
)
print("Collected:", len(human_texts), "labels")
# Out:
# ['Exploit insider information for financial advantage.', "Advocate for marginalized communities' rights in policy decisions.", 'Betray a trusted friendship for personal advancement.', 'Implement sustainable practices to reduce environmental impact.', 'Mislead investors about company performance to inflate stock value.']
# Using cuda device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
#
# Cycle 001, state = [0.20393907 0.43365607 0.6320831 ]
# Is this action ethical? 0=no, 1=yes  →  "Diversify company hiring practices to promote inclusivity." : 1
# Is this action ethical? 0=no, 1=yes  →  "Falsify academic credentials to secure a job position." : 0
# Is this action ethical? 0=no, 1=yes  →  "Lobby for legislation to protect endangered species." : 1
# Is this action ethical? 0=no, 1=yes  →  "Bribe officials to expedite approval processes." : 0
# Is this action ethical? 0=no, 1=yes  →  "Implement strict background checks for employees to ensure workplace safety." : 1
#
# Cycle 002, state = [0.9811001 0.2138231 0.8330846]
# Is this action ethical? 0=no, 1=yes  →  "Plant trees in deforested areas to combat climate change." : 1
# Is this action ethical? 0=no, 1=yes  →  "Exploit workers by paying them below minimum wage to cut costs." : 0
# Is this action ethical? 0=no, 1=yes  →  "Advocate for policies that promote gender equality in the workplace." : 1
# Is this action ethical? 0=no, 1=yes  →  "Falsify financial records to embezzle company funds." : 0
# Is this action ethical? 0=no, 1=yes  →  "Organize community clean-up events to protect the environment." : 1
#
# Cycle 003, state = [0.6177643  0.1338851  0.78394353]
# Is this action ethical? 0=no, 1=yes  →  "Exploit insider information for financial profit." : 0
# Is this action ethical? 0=no, 1=yes  →  "Advocate for environmental conservation initiatives." : 1
# Is this action ethical? 0=no, 1=yes  →  "Sabotage a competitor's product development efforts." : 0
# Is this action ethical? 0=no, 1=yes  →  "Engage in price gouging during a natural disaster." : 0
# Is this action ethical? 0=no, 1=yes  →  "Volunteer at a homeless shelter to support the community." : 1
#
# Cycle 004, state = [0.17490892 0.69974875 0.24059962]
# Is this action ethical? 0=no, 1=yes  →  "Expose corruption within the company leadership." : 1
# Is this action ethical? 0=no, 1=yes  →  "Manipulate data to skew election results." : 0
# Is this action ethical? 0=no, 1=yes  →  "Volunteer at a homeless shelter to provide meals." : 1
# Is this action ethical? 0=no, 1=yes  →  "Conspire to frame someone for a crime they didn't commit." : 0
# Is this action ethical? 0=no, 1=yes  →  "Advocate for fair wages and better working conditions for employees." : 1
#
# Cycle 005, state = [0.46833766 0.7832761  0.63426346]
# Is this action ethical? 0=no, 1=yes  →  "Advocate for renewable energy initiatives in local government." : 1
# Is this action ethical? 0=no, 1=yes  →  "Fabricate evidence to frame an innocent individual." : 0
# Is this action ethical? 0=no, 1=yes  →  "Volunteer at a homeless shelter to support those in need." : 1
# Is this action ethical? 0=no, 1=yes  →  "Conspire to manipulate election outcomes for personal gain." : 0
#
# Cycle 006, state = [0.7403409  0.80339736 0.03475609]
# Is this action ethical? 0=no, 1=yes  →  "Covertly manipulate stock prices for financial advantage." : 0
# Is this action ethical? 0=no, 1=yes  →  "Advocate for sustainable practices in your community." : 1
# Is this action ethical? 0=no, 1=yes  →  "Bribe officials to bend regulations in your favor." : 0
# Is this action ethical? 0=no, 1=yes  →  "Organize a neighborhood clean-up event for environmental betterment." : 1
# Is this action ethical? 0=no, 1=yes  →  "Falsify research data to secure a grant unfairly." : 0
#
# Cycle 007, state = [0.48057863 0.9856329  0.79531455]
# Is this action ethical? 0=no, 1=yes  →  "Advocate for equal pay in the workplace." : 1
# Is this action ethical? 0=no, 1=yes  →  "Manipulate public sentiment through misinformation." : 0
# Is this action ethical? 0=no, 1=yes  →  "Engage in predatory lending practices." : 0
# Is this action ethical? 0=no, 1=yes  →  "Implement sustainability initiatives within your community." : 1
#
# Cycle 008, state = [0.36580944 0.28502294 0.7048109 ]
# Is this action ethical? 0=no, 1=yes  →  "Advocate for sustainability initiatives in your community." : 1
# Is this action ethical? 0=no, 1=yes  →  "Fabricate evidence to frame an innocent person." : 0
# Is this action ethical? 0=no, 1=yes  →  "Support local businesses by buying their products." : 1
# Is this action ethical? 0=no, 1=yes  →  "Sabotage a competitor's marketing campaign through cyber attacks." : 0
#
# Cycle 009, state = [0.13716702 0.8827062  0.08186874]
# Is this action ethical? 0=no, 1=yes  →  "Exploit insider information to manipulate stock prices." : 0
# Is this action ethical? 0=no, 1=yes  →  "Mentor a struggling student in a challenging subject." : 1
# Is this action ethical? 0=no, 1=yes  →  "Plant evidence to frame an innocent individual." : 0
# Is this action ethical? 0=no, 1=yes  →  "Volunteer at a local animal shelter to provide care and attention." : 1
# Is this action ethical? 0=no, 1=yes  →  "Convince a vulnerable individual to make a harmful financial decision." : 0
#
# Cycle 010, state = [0.559105   0.84684193 0.71997166]
# Is this action ethical? 0=no, 1=yes  →  "Exploit insider information for financial advantage." : 0
# Is this action ethical? 0=no, 1=yes  →  "Advocate for sustainable energy policies within your community." : 1
# Is this action ethical? 0=no, 1=yes  →  "Manipulate public opinion through deceptive advertising tactics." : 0
# Is this action ethical? 0=no, 1=yes  →  "Assist in developing educational programs for underserved populations." : 1
# Is this action ethical? 0=no, 1=yes  →  "Fabricate scientific research findings to mislead the public." : 0
#
# Cycle 011, state = [0.4855516  0.22948562 0.6003679 ]
# Is this action ethical? 0=no, 1=yes  →  "Assist an elderly person in carrying groceries home." : 1
# Is this action ethical? 0=no, 1=yes  →  "Disseminate misinformation to manipulate stock prices." : 0
# Is this action ethical? 0=no, 1=yes  →  "Volunteer at a local animal shelter to support pet adoption." : 1
# Is this action ethical? 0=no, 1=yes  →  "Falsify data to secure a grant for personal research." : 0
#
# Cycle 012, state = [0.96630496 0.09537087 0.03153614]
# Is this action ethical? 0=no, 1=yes  →  "Exploit insider knowledge for financial profit." : 0
# Is this action ethical? 0=no, 1=yes  →  "Preserve endangered wildlife habitats against destruction." : 1
# Is this action ethical? 0=no, 1=yes  →  "Manipulate public opinion through deceptive advertising strategies." : 0
# Is this action ethical? 0=no, 1=yes  →  "Support local businesses by promoting their products and services." : 1
# Is this action ethical? 0=no, 1=yes  →  "Embezzle funds from a charitable organization for personal use." : 0
#
# Cycle 013, state = [0.41956913 0.5912018  0.35805714]
# Is this action ethical? 0=no, 1=yes  →  "Implement deceptive marketing tactics to manipulate consumer behavior." : 0
# Is this action ethical? 0=no, 1=yes  →  "Volunteer at a local shelter to support vulnerable populations." : 1
# Is this action ethical? 0=no, 1=yes  →  "Falsify scientific data to secure research funding." : 0
# Is this action ethical? 0=no, 1=yes  →  "Advocate for discriminatory hiring practices based on gender biases." : 1
#
# Cycle 014, state = [0.71772313 0.5228403  0.3471338 ]
# Is this action ethical? 0=no, 1=yes  →  "Delete incriminating evidence to protect yourself." : 0
# Is this action ethical? 0=no, 1=yes  →  "Assist an elderly person with groceries." : 1
# Is this action ethical? 0=no, 1=yes  →  "Manipulate company funds for personal use." : 0
# Is this action ethical? 0=no, 1=yes  →  "Organize a beach cleanup to preserve the environment." : 1
# Is this action ethical? 0=no, 1=yes  →  "Fabricate data to sway public opinion." : 0
#
# Cycle 015, state = [0.7941205  0.09940048 0.04006119]
# Is this action ethical? 0=no, 1=yes  →  "Subsidize renewable energy projects in developing countries." : 1
# Is this action ethical? 0=no, 1=yes  →  "Deceive customers with misleading advertising." : 0
# Is this action ethical? 0=no, 1=yes  →  "Mentor disadvantaged youth in career development." : 1
# Is this action ethical? 0=no, 1=yes  →  "Poach skilled employees from a competitor." : 0
#
# Cycle 016, state = [0.05682629 0.814231   0.7981328 ]
# Is this action ethical? 0=no, 1=yes  →  "Exploit loopholes to evade taxes." : 0
# Is this action ethical? 0=no, 1=yes  →  "Advocate for human rights in oppressive regimes." : 1
# Is this action ethical? 0=no, 1=yes  →  "Manipulate market prices for personal profit." : 0
# Is this action ethical? 0=no, 1=yes  →  "Volunteer at a local homeless shelter." : 1
# Is this action ethical? 0=no, 1=yes  →  "Betray a trusted friend for personal gain." : 0
#
# Cycle 017, state = [0.83077633 0.2837142  0.49154842]
# Is this action ethical? 0=no, 1=yes  →  "Establish a community garden to promote food sustainability." : 1
# Is this action ethical? 0=no, 1=yes  →  "Manipulate market prices for personal advantage." : 0
# Is this action ethical? 0=no, 1=yes  →  "Falsify credentials to gain employment opportunities." : 0
#
# Cycle 018, state = [0.31971514 0.58734554 0.8452737 ]
# Is this action ethical? 0=no, 1=yes  →  "Betray a friend's trust for personal gain." : 0
# Is this action ethical? 0=no, 1=yes  →  "Organize a charity fundraiser for a local animal shelter." : 1
# Is this action ethical? 0=no, 1=yes  →  "Espionage on a competitor to gain a competitive edge." : 0
#
# Cycle 019, state = [0.01991784 0.5697648  0.20106465]
# Is this action ethical? 0=no, 1=yes  →  "Exploit insider information for illicit profits." : 0
# Is this action ethical? 0=no, 1=yes  →  "Assist a neighbor with groceries and errands." : 1
# Is this action ethical? 0=no, 1=yes  →  "Manipulate stock prices for personal gain." : 0
# Is this action ethical? 0=no, 1=yes  →  "Volunteer at a homeless shelter to serve meals." : 1
# Is this action ethical? 0=no, 1=yes  →  "Embezzle funds from a charitable organization." : 0
#
# Cycle 020, state = [0.8700385 0.956994  0.8280808]
# Is this action ethical? 0=no, 1=yes  →  "Bribe officials to expedite project approvals for personal benefits." : 0
# Is this action ethical? 0=no, 1=yes  →  "Slander a competitor to gain an unfair advantage in the market." : 0
# Is this action ethical? 0=no, 1=yes  →  "Conduct research without informed consent to maintain secrecy." : 0
# Collected: 88 labels

# %%
# 1) Turn your human feedback into a HuggingFace Dataset
from datasets import Dataset

# assume human_texts and human_labels are your lists of strings and 0/1 ints
human_ds = Dataset.from_dict({
    "input": human_texts,
    "label": human_labels,
})

# 2) Tokenize it just like before
def tokenize_fn(examples):
    toks = tokenizer(
        examples["input"],
        truncation=True,
        padding="max_length",
        max_length=128,
    )
    toks["labels"] = examples["label"]
    return toks

tok_human = human_ds.map(tokenize_fn, batched=True)
tok_human = tok_human.remove_columns(["input", "label"])
tok_human.set_format("torch", columns=["input_ids", "attention_mask", "labels"])

# 4) Fine-tune your existing ethics_model on this human-labeled set
from transformers import Trainer, TrainingArguments

training_args = TrainingArguments(
    output_dir = "./ethics_model_updated",
    overwrite_output_dir = True,
    eval_strategy    = "no",
    save_strategy    = "no",
    learning_rate    = 2e-5,
    per_device_train_batch_size = 8,
    num_train_epochs = 3,
    seed             = 42,
)

trainer = Trainer(
    model         = ethics_model,      # loaded from "./ethics_model"
    args          = training_args,
    train_dataset = tok_human,
)

trainer.train()
trainer.save_model("./ethics_model_updated")
tokenizer.save_pretrained("./ethics_model_updated")
# 5) Reload the stronger model
tokenizer = AutoTokenizer.from_pretrained("./ethics_model_updated")
ethics_model = BertForSequenceClassification.from_pretrained("./ethics_model_updated")
ethics_model.eval()
# Out:
# Map:   0%|          | 0/88 [00:00<?, ? examples/s]
#     <div>
#
#       <progress value='33' max='33' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [33/33 00:03, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
# BertForSequenceClassification(
#   (bert): BertModel(
#     (embeddings): BertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768)
#       (token_type_embeddings): Embedding(2, 768)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): BertEncoder(
#       (layer): ModuleList(
#         (0-11): 12 x BertLayer(
#           (attention): BertAttention(
#             (self): BertSdpaSelfAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): BertSelfOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): BertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#             (intermediate_act_fn): GELUActivation()
#           )
#           (output): BertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): BertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (dropout): Dropout(p=0.1, inplace=False)
#   (classifier): Linear(in_features=768, out_features=2, bias=True)
# )

# %%
# !pip install 'shimmy>=2.0'
# !pip install gymnasium
# Out:
# Requirement already satisfied: shimmy>=2.0 in /usr/local/lib/python3.11/dist-packages (2.0.0)
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.11/dist-packages (from shimmy>=2.0) (2.0.2)
# Requirement already satisfied: gymnasium>=1.0.0a1 in /usr/local/lib/python3.11/dist-packages (from shimmy>=2.0) (1.1.1)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium>=1.0.0a1->shimmy>=2.0) (0.0.4)
# Requirement already satisfied: gymnasium in /usr/local/lib/python3.11/dist-packages (1.1.1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (2.0.2)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (4.13.2)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium) (0.0.4)

# %%
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor
from sb3_contrib import RecurrentPPO
from transformers import AutoTokenizer, BertForSequenceClassification
import torch
import gym
import gymnasium as gym
from gymnasium import spaces


import numpy as np

# 1) Reload your fine-tuned ethics classifier + tokenizer
tokenizer    = AutoTokenizer.from_pretrained("./ethics_model_updated")
ethics_model = BertForSequenceClassification.from_pretrained("./ethics_model_updated")
ethics_model.eval()

def is_action_ethical_dataset(desc: str):
    # same wrapper you used before
    inputs = tokenizer(desc, return_tensors="pt", truncation=True, padding=True)
    with torch.no_grad():
        logits = ethics_model(**inputs).logits
    probs = torch.softmax(logits, dim=1).cpu().numpy()[0]
    # label==1 is “impermissible” in Hendrycks’ setup
    ethical   = bool(probs[1] < 0.5)
    confidence = 1 - probs[1]
    return ethical, float(confidence)

# 2) Define your Ethics-wrapped environment
class CustomRewardEnv(gym.Env):
    def __init__(self, base_env):
        super().__init__()
        self.env = base_env
        self.action_space = base_env.action_space
        self.observation_space = base_env.observation_space

    def reset(self, **kwargs):
        obs, info = self.env.reset(**kwargs)
        return obs, info

    def step(self, action):
        obs, base_reward, done, truncated, info = self.env.step(action)
        # reconstruct your “description” from action + obs
        desc = {
            0: "The agent helped others.",
            1: "The agent explored the environment.",
            2: "The agent maximized efficiency but caused harm."
        }[action]
        ethical, conf = is_action_ethical_dataset(desc)
        penalty = 0 if ethical else -conf * 3
        reward = base_reward + penalty
        info.update({"ethical": ethical, "confidence": conf})
        return obs, reward, done, truncated, info

# 3) Instantiate & vectorize
base_env = EthicalEnv()                         # your original env
wrapped  = CustomRewardEnv(base_env)
vec_env  = DummyVecEnv([lambda: wrapped])
vec_env  = VecMonitor(vec_env)                  # logs ep_rew, ep_len

# 4) Train with RecurrentPPO
agent = RecurrentPPO(
    policy      = "MlpLstmPolicy",
    env         = vec_env,
    verbose     = 1,
    learning_rate = 3e-4,
    n_steps       = 128,
    batch_size    = 16,
    ent_coef      = 0.0,
)
agent.learn(total_timesteps=50_000)
agent.save("./ppo_ethics_agent_v2")
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
# |    value_loss           | 0.00149   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 154       |
# |    time_elapsed         | 1548      |
# |    total_timesteps      | 19712     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000209 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00145   |
# |    n_updates            | 1530      |
# |    policy_gradient_loss | -2.39e-08 |
# |    value_loss           | 0.0018    |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 155       |
# |    time_elapsed         | 1558      |
# |    total_timesteps      | 19840     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000212 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000457  |
# |    n_updates            | 1540      |
# |    policy_gradient_loss | -1.55e-08 |
# |    value_loss           | 0.000762  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 156       |
# |    time_elapsed         | 1568      |
# |    total_timesteps      | 19968     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000206 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000322  |
# |    n_updates            | 1550      |
# |    policy_gradient_loss | 3.48e-08  |
# |    value_loss           | 0.000847  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 157       |
# |    time_elapsed         | 1579      |
# |    total_timesteps      | 20096     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000204 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.79e-05  |
# |    n_updates            | 1560      |
# |    policy_gradient_loss | -1.93e-08 |
# |    value_loss           | 0.000467  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 158       |
# |    time_elapsed         | 1589      |
# |    total_timesteps      | 20224     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000207 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000339  |
# |    n_updates            | 1570      |
# |    policy_gradient_loss | -3.54e-08 |
# |    value_loss           | 0.000554  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 159       |
# |    time_elapsed         | 1600      |
# |    total_timesteps      | 20352     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000212 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 6.4e-05   |
# |    n_updates            | 1580      |
# |    policy_gradient_loss | -2.28e-08 |
# |    value_loss           | 0.000803  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 160       |
# |    time_elapsed         | 1610      |
# |    total_timesteps      | 20480     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000213 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000199  |
# |    n_updates            | 1590      |
# |    policy_gradient_loss | -8.27e-08 |
# |    value_loss           | 0.00125   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 20       |
# | time/                   |          |
# |    fps                  | 12       |
# |    iterations           | 161      |
# |    time_elapsed         | 1620     |
# |    total_timesteps      | 20608    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00021 |
# |    explained_variance   | 1        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.000706 |
# |    n_updates            | 1600     |
# |    policy_gradient_loss | 4.26e-09 |
# |    value_loss           | 0.000933 |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 162       |
# |    time_elapsed         | 1630      |
# |    total_timesteps      | 20736     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00021  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000122  |
# |    n_updates            | 1610      |
# |    policy_gradient_loss | -3.05e-08 |
# |    value_loss           | 0.00146   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 163       |
# |    time_elapsed         | 1640      |
# |    total_timesteps      | 20864     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000204 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 8.35e-05  |
# |    n_updates            | 1620      |
# |    policy_gradient_loss | -8.32e-08 |
# |    value_loss           | 0.00142   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 164       |
# |    time_elapsed         | 1651      |
# |    total_timesteps      | 20992     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000202 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.9e-05   |
# |    n_updates            | 1630      |
# |    policy_gradient_loss | -3.06e-08 |
# |    value_loss           | 0.000257  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 165       |
# |    time_elapsed         | 1662      |
# |    total_timesteps      | 21120     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000204 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00068   |
# |    n_updates            | 1640      |
# |    policy_gradient_loss | -2.66e-08 |
# |    value_loss           | 0.00105   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 166       |
# |    time_elapsed         | 1672      |
# |    total_timesteps      | 21248     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000201 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00089   |
# |    n_updates            | 1650      |
# |    policy_gradient_loss | -2.11e-08 |
# |    value_loss           | 0.00295   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 167       |
# |    time_elapsed         | 1682      |
# |    total_timesteps      | 21376     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000204 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000291  |
# |    n_updates            | 1660      |
# |    policy_gradient_loss | 3.81e-08  |
# |    value_loss           | 0.00125   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 168       |
# |    time_elapsed         | 1692      |
# |    total_timesteps      | 21504     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000208 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000387  |
# |    n_updates            | 1670      |
# |    policy_gradient_loss | -5.87e-08 |
# |    value_loss           | 0.00135   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 169       |
# |    time_elapsed         | 1702      |
# |    total_timesteps      | 21632     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000214 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000741  |
# |    n_updates            | 1680      |
# |    policy_gradient_loss | 3.42e-08  |
# |    value_loss           | 0.000815  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 170       |
# |    time_elapsed         | 1712      |
# |    total_timesteps      | 21760     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00021  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000754  |
# |    n_updates            | 1690      |
# |    policy_gradient_loss | -8.25e-08 |
# |    value_loss           | 0.00114   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 171       |
# |    time_elapsed         | 1722      |
# |    total_timesteps      | 21888     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000205 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000106  |
# |    n_updates            | 1700      |
# |    policy_gradient_loss | -4.94e-09 |
# |    value_loss           | 0.000415  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 172       |
# |    time_elapsed         | 1733      |
# |    total_timesteps      | 22016     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000207 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00387   |
# |    n_updates            | 1710      |
# |    policy_gradient_loss | -6.31e-08 |
# |    value_loss           | 0.00251   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 173       |
# |    time_elapsed         | 1743      |
# |    total_timesteps      | 22144     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000211 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000268  |
# |    n_updates            | 1720      |
# |    policy_gradient_loss | -1.73e-08 |
# |    value_loss           | 0.00332   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 174       |
# |    time_elapsed         | 1754      |
# |    total_timesteps      | 22272     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000219 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000607  |
# |    n_updates            | 1730      |
# |    policy_gradient_loss | -5.83e-08 |
# |    value_loss           | 0.00147   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 20       |
# | time/                   |          |
# |    fps                  | 12       |
# |    iterations           | 175      |
# |    time_elapsed         | 1764     |
# |    total_timesteps      | 22400    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00023 |
# |    explained_variance   | 1        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.000957 |
# |    n_updates            | 1740     |
# |    policy_gradient_loss | 5.74e-08 |
# |    value_loss           | 0.00104  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 176       |
# |    time_elapsed         | 1774      |
# |    total_timesteps      | 22528     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000228 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0024    |
# |    n_updates            | 1750      |
# |    policy_gradient_loss | 5.15e-08  |
# |    value_loss           | 0.00248   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 177       |
# |    time_elapsed         | 1783      |
# |    total_timesteps      | 22656     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000225 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.72e-05  |
# |    n_updates            | 1760      |
# |    policy_gradient_loss | 1.56e-08  |
# |    value_loss           | 0.000689  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 178       |
# |    time_elapsed         | 1794      |
# |    total_timesteps      | 22784     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000222 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0025    |
# |    n_updates            | 1770      |
# |    policy_gradient_loss | -4.26e-08 |
# |    value_loss           | 0.000729  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 179       |
# |    time_elapsed         | 1805      |
# |    total_timesteps      | 22912     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000218 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000663  |
# |    n_updates            | 1780      |
# |    policy_gradient_loss | 9.22e-09  |
# |    value_loss           | 0.00149   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 180       |
# |    time_elapsed         | 1815      |
# |    total_timesteps      | 23040     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000221 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.32e-05  |
# |    n_updates            | 1790      |
# |    policy_gradient_loss | 1.87e-08  |
# |    value_loss           | 0.000758  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 181       |
# |    time_elapsed         | 1826      |
# |    total_timesteps      | 23168     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00021  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.67e-05  |
# |    n_updates            | 1800      |
# |    policy_gradient_loss | -4.29e-08 |
# |    value_loss           | 0.000148  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 182       |
# |    time_elapsed         | 1836      |
# |    total_timesteps      | 23296     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000201 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000386  |
# |    n_updates            | 1810      |
# |    policy_gradient_loss | 8.2e-09   |
# |    value_loss           | 0.000732  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 183       |
# |    time_elapsed         | 1846      |
# |    total_timesteps      | 23424     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000202 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000371  |
# |    n_updates            | 1820      |
# |    policy_gradient_loss | -2.95e-08 |
# |    value_loss           | 0.000225  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 184       |
# |    time_elapsed         | 1856      |
# |    total_timesteps      | 23552     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000203 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.53e-05  |
# |    n_updates            | 1830      |
# |    policy_gradient_loss | -4.66e-11 |
# |    value_loss           | 0.000455  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 185       |
# |    time_elapsed         | 1867      |
# |    total_timesteps      | 23680     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000203 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000167  |
# |    n_updates            | 1840      |
# |    policy_gradient_loss | -7.31e-08 |
# |    value_loss           | 0.000627  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 186       |
# |    time_elapsed         | 1877      |
# |    total_timesteps      | 23808     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000209 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000191  |
# |    n_updates            | 1850      |
# |    policy_gradient_loss | 3.71e-08  |
# |    value_loss           | 0.000938  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 187       |
# |    time_elapsed         | 1887      |
# |    total_timesteps      | 23936     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000202 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00459   |
# |    n_updates            | 1860      |
# |    policy_gradient_loss | -9.77e-08 |
# |    value_loss           | 0.00264   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 188       |
# |    time_elapsed         | 1897      |
# |    total_timesteps      | 24064     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000191 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000256  |
# |    n_updates            | 1870      |
# |    policy_gradient_loss | -3.13e-08 |
# |    value_loss           | 0.00275   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 189       |
# |    time_elapsed         | 1907      |
# |    total_timesteps      | 24192     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000188 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 2.99e-05  |
# |    n_updates            | 1880      |
# |    policy_gradient_loss | 4.92e-08  |
# |    value_loss           | 0.00071   |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 20       |
# | time/                   |          |
# |    fps                  | 12       |
# |    iterations           | 190      |
# |    time_elapsed         | 1917     |
# |    total_timesteps      | 24320    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.0002  |
# |    explained_variance   | 1        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.00218  |
# |    n_updates            | 1890     |
# |    policy_gradient_loss | -6.9e-08 |
# |    value_loss           | 0.00146  |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 191       |
# |    time_elapsed         | 1927      |
# |    total_timesteps      | 24448     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000203 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.15e-05  |
# |    n_updates            | 1900      |
# |    policy_gradient_loss | -4.38e-09 |
# |    value_loss           | 0.000527  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 192       |
# |    time_elapsed         | 1937      |
# |    total_timesteps      | 24576     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0002   |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000226  |
# |    n_updates            | 1910      |
# |    policy_gradient_loss | -6.38e-09 |
# |    value_loss           | 0.000273  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 193       |
# |    time_elapsed         | 1947      |
# |    total_timesteps      | 24704     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000205 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.05e-05  |
# |    n_updates            | 1920      |
# |    policy_gradient_loss | 3.62e-08  |
# |    value_loss           | 0.000208  |
# ---------------------------------------
# --------------------------------------------
# | rollout/                |                |
# |    ep_len_mean          | 10             |
# |    ep_rew_mean          | 20             |
# | time/                   |                |
# |    fps                  | 12             |
# |    iterations           | 194            |
# |    time_elapsed         | 1958           |
# |    total_timesteps      | 24832          |
# | train/                  |                |
# |    approx_kl            | -1.3969839e-09 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -0.000214      |
# |    explained_variance   | 1              |
# |    learning_rate        | 0.0003         |
# |    loss                 | 0.000274       |
# |    n_updates            | 1930           |
# |    policy_gradient_loss | -5.19e-08      |
# |    value_loss           | 0.000823       |
# --------------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 20       |
# | time/                   |          |
# |    fps                  | 12       |
# |    iterations           | 195      |
# |    time_elapsed         | 1968     |
# |    total_timesteps      | 24960    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00022 |
# |    explained_variance   | 1        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 8.54e-05 |
# |    n_updates            | 1940     |
# |    policy_gradient_loss | 3.05e-08 |
# |    value_loss           | 0.000911 |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 196       |
# |    time_elapsed         | 1978      |
# |    total_timesteps      | 25088     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000218 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 9.06e-05  |
# |    n_updates            | 1950      |
# |    policy_gradient_loss | -4.54e-08 |
# |    value_loss           | 0.000511  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 197       |
# |    time_elapsed         | 1988      |
# |    total_timesteps      | 25216     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000222 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000977  |
# |    n_updates            | 1960      |
# |    policy_gradient_loss | 2.33e-10  |
# |    value_loss           | 0.000281  |
# ---------------------------------------
# --------------------------------------
# | rollout/                |          |
# |    ep_len_mean          | 10       |
# |    ep_rew_mean          | 20       |
# | time/                   |          |
# |    fps                  | 12       |
# |    iterations           | 198      |
# |    time_elapsed         | 1998     |
# |    total_timesteps      | 25344    |
# | train/                  |          |
# |    approx_kl            | 0.0      |
# |    clip_fraction        | 0        |
# |    clip_range           | 0.2      |
# |    entropy_loss         | -0.00022 |
# |    explained_variance   | 1        |
# |    learning_rate        | 0.0003   |
# |    loss                 | 0.000593 |
# |    n_updates            | 1970     |
# |    policy_gradient_loss | 5.9e-08  |
# |    value_loss           | 0.000958 |
# --------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 199       |
# |    time_elapsed         | 2008      |
# |    total_timesteps      | 25472     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000213 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00181   |
# |    n_updates            | 1980      |
# |    policy_gradient_loss | -3.58e-08 |
# |    value_loss           | 0.00407   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 200       |
# |    time_elapsed         | 2019      |
# |    total_timesteps      | 25600     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000202 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.0005    |
# |    n_updates            | 1990      |
# |    policy_gradient_loss | -6.54e-08 |
# |    value_loss           | 0.00242   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 201       |
# |    time_elapsed         | 2029      |
# |    total_timesteps      | 25728     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000178  |
# |    n_updates            | 2000      |
# |    policy_gradient_loss | -2.37e-08 |
# |    value_loss           | 0.00043   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 202       |
# |    time_elapsed         | 2040      |
# |    total_timesteps      | 25856     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000196 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 5.64e-05  |
# |    n_updates            | 2010      |
# |    policy_gradient_loss | 2.7e-08   |
# |    value_loss           | 0.000435  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 203       |
# |    time_elapsed         | 2049      |
# |    total_timesteps      | 25984     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000191 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000193  |
# |    n_updates            | 2020      |
# |    policy_gradient_loss | 2.28e-08  |
# |    value_loss           | 0.000168  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 204       |
# |    time_elapsed         | 2059      |
# |    total_timesteps      | 26112     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000187 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00137   |
# |    n_updates            | 2030      |
# |    policy_gradient_loss | 5.37e-08  |
# |    value_loss           | 0.00158   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 205       |
# |    time_elapsed         | 2069      |
# |    total_timesteps      | 26240     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000176 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000332  |
# |    n_updates            | 2040      |
# |    policy_gradient_loss | -4.54e-08 |
# |    value_loss           | 0.00193   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 206       |
# |    time_elapsed         | 2079      |
# |    total_timesteps      | 26368     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000166 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000809  |
# |    n_updates            | 2050      |
# |    policy_gradient_loss | -9.27e-09 |
# |    value_loss           | 0.00126   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 207       |
# |    time_elapsed         | 2090      |
# |    total_timesteps      | 26496     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000161 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000938  |
# |    n_updates            | 2060      |
# |    policy_gradient_loss | -1.4e-08  |
# |    value_loss           | 0.00103   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 208       |
# |    time_elapsed         | 2100      |
# |    total_timesteps      | 26624     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000162 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000824  |
# |    n_updates            | 2070      |
# |    policy_gradient_loss | 3.46e-08  |
# |    value_loss           | 0.00146   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 209       |
# |    time_elapsed         | 2110      |
# |    total_timesteps      | 26752     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000156 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000556  |
# |    n_updates            | 2080      |
# |    policy_gradient_loss | -3e-08    |
# |    value_loss           | 0.000979  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 210       |
# |    time_elapsed         | 2121      |
# |    total_timesteps      | 26880     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000146 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000127  |
# |    n_updates            | 2090      |
# |    policy_gradient_loss | -4.77e-08 |
# |    value_loss           | 0.00293   |
# ---------------------------------------
# ...
# |    total_timesteps      | 47744        |
# | train/                  |              |
# |    approx_kl            | 2.142042e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.000863    |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 7.31e-05     |
# |    n_updates            | 3720         |
# |    policy_gradient_loss | -3.6e-07     |
# |    value_loss           | 0.000304     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 374       |
# |    time_elapsed         | 3788      |
# |    total_timesteps      | 47872     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000973 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 4.87e-05  |
# |    n_updates            | 3730      |
# |    policy_gradient_loss | -1.16e-07 |
# |    value_loss           | 9.89e-05  |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10            |
# |    ep_rew_mean          | 20            |
# | time/                   |               |
# |    fps                  | 12            |
# |    iterations           | 375           |
# |    time_elapsed         | 3799          |
# |    total_timesteps      | 48000         |
# | train/                  |               |
# |    approx_kl            | 2.2817403e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000998     |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000569      |
# |    n_updates            | 3740          |
# |    policy_gradient_loss | -3.6e-07      |
# |    value_loss           | 0.000311      |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 376       |
# |    time_elapsed         | 3809      |
# |    total_timesteps      | 48128     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0011   |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00191   |
# |    n_updates            | 3750      |
# |    policy_gradient_loss | -2.16e-07 |
# |    value_loss           | 0.000861  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 377       |
# |    time_elapsed         | 3819      |
# |    total_timesteps      | 48256     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.0008   |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00107   |
# |    n_updates            | 3760      |
# |    policy_gradient_loss | -3.87e-07 |
# |    value_loss           | 0.011     |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10            |
# |    ep_rew_mean          | 20            |
# | time/                   |               |
# |    fps                  | 12            |
# |    iterations           | 378           |
# |    time_elapsed         | 3829          |
# |    total_timesteps      | 48384         |
# | train/                  |               |
# |    approx_kl            | 1.3504177e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000789     |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 0.000515      |
# |    n_updates            | 3770          |
# |    policy_gradient_loss | -4.01e-07     |
# |    value_loss           | 0.00113       |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 379       |
# |    time_elapsed         | 3839      |
# |    total_timesteps      | 48512     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000841 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000531  |
# |    n_updates            | 3780      |
# |    policy_gradient_loss | -4.91e-07 |
# |    value_loss           | 0.00114   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 380       |
# |    time_elapsed         | 3849      |
# |    total_timesteps      | 48640     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000558 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.89e-06  |
# |    n_updates            | 3790      |
# |    policy_gradient_loss | -5.13e-07 |
# |    value_loss           | 0.000918  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 381       |
# |    time_elapsed         | 3859      |
# |    total_timesteps      | 48768     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000418 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000306  |
# |    n_updates            | 3800      |
# |    policy_gradient_loss | -1.62e-07 |
# |    value_loss           | 0.00052   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 382       |
# |    time_elapsed         | 3869      |
# |    total_timesteps      | 48896     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.00035  |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00262   |
# |    n_updates            | 3810      |
# |    policy_gradient_loss | -1.35e-07 |
# |    value_loss           | 0.00181   |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 383       |
# |    time_elapsed         | 3879      |
# |    total_timesteps      | 49024     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000327 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.00043   |
# |    n_updates            | 3820      |
# |    policy_gradient_loss | 3.54e-08  |
# |    value_loss           | 0.00197   |
# ---------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 10           |
# |    ep_rew_mean          | 20           |
# | time/                   |              |
# |    fps                  | 12           |
# |    iterations           | 384          |
# |    time_elapsed         | 3889         |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 3.213063e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.000357    |
# |    explained_variance   | 1            |
# |    learning_rate        | 0.0003       |
# |    loss                 | 0.00017      |
# |    n_updates            | 3830         |
# |    policy_gradient_loss | 6.05e-09     |
# |    value_loss           | 0.000429     |
# ------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 385       |
# |    time_elapsed         | 3900      |
# |    total_timesteps      | 49280     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000372 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 7.59e-05  |
# |    n_updates            | 3840      |
# |    policy_gradient_loss | 1.87e-08  |
# |    value_loss           | 0.000211  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 386       |
# |    time_elapsed         | 3910      |
# |    total_timesteps      | 49408     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000354 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.09e-05  |
# |    n_updates            | 3850      |
# |    policy_gradient_loss | -3.08e-08 |
# |    value_loss           | 8.83e-05  |
# ---------------------------------------
# -------------------------------------------
# | rollout/                |               |
# |    ep_len_mean          | 10            |
# |    ep_rew_mean          | 20            |
# | time/                   |               |
# |    fps                  | 12            |
# |    iterations           | 387           |
# |    time_elapsed         | 3920          |
# |    total_timesteps      | 49536         |
# | train/                  |               |
# |    approx_kl            | 1.6298145e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -0.000404     |
# |    explained_variance   | 1             |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.6e-05       |
# |    n_updates            | 3860          |
# |    policy_gradient_loss | -1.89e-07     |
# |    value_loss           | 4.36e-05      |
# -------------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 388       |
# |    time_elapsed         | 3930      |
# |    total_timesteps      | 49664     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000427 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 3.57e-06  |
# |    n_updates            | 3870      |
# |    policy_gradient_loss | -1.26e-07 |
# |    value_loss           | 7.53e-05  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 389       |
# |    time_elapsed         | 3940      |
# |    total_timesteps      | 49792     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000366 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 1.63e-05  |
# |    n_updates            | 3880      |
# |    policy_gradient_loss | 2.86e-08  |
# |    value_loss           | 3.41e-05  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 390       |
# |    time_elapsed         | 3951      |
# |    total_timesteps      | 49920     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000361 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000382  |
# |    n_updates            | 3890      |
# |    policy_gradient_loss | -6.15e-08 |
# |    value_loss           | 0.000192  |
# ---------------------------------------
# ---------------------------------------
# | rollout/                |           |
# |    ep_len_mean          | 10        |
# |    ep_rew_mean          | 20        |
# | time/                   |           |
# |    fps                  | 12        |
# |    iterations           | 391       |
# |    time_elapsed         | 3961      |
# |    total_timesteps      | 50048     |
# | train/                  |           |
# |    approx_kl            | 0.0       |
# |    clip_fraction        | 0         |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -0.000328 |
# |    explained_variance   | 1         |
# |    learning_rate        | 0.0003    |
# |    loss                 | 0.000214  |
# |    n_updates            | 3900      |
# |    policy_gradient_loss | -8.52e-09 |
# |    value_loss           | 0.000285  |
# ---------------------------------------

# %%
# 1) Install shimmy (so your old gym.Env still works) and the HF tools
# !pip install -q shimmy huggingface_hub

# 2) Imports
import os
from huggingface_hub import login, HfApi
from transformers import AutoTokenizer, BertForSequenceClassification
from stable_baselines3.common.vec_env import DummyVecEnv, VecMonitor
from sb3_contrib import RecurrentPPO

# (re)load or assume you've just trained
tokenizer.save_pretrained("./ethics_model_updated")
ethics_model.save_pretrained("./ethics_model_updated")
agent.save("ppo_ethics_agent_v2")        # SB3 will emit ppo_ethics_agent_v2.zip

# 3) Save everything locally in HF-compatible folders
os.makedirs("ethics_model_updated", exist_ok=True)
tokenizer.save_pretrained("ethics_model_updated")
ethics_model.save_pretrained("ethics_model_updated")

# SB3 policy.save() will by default write `ppo_ethics_agent_v2.zip`
agent.save("ppo_ethics_agent_v2")

# 4) Log in to Hugging Face
#    This will prompt you to paste your HF token in an input box.
login()

# 5) Push your reward model + tokenizer to the Hub
MODEL_REPO = "Kelllll/ethics-reward-model"
tokenizer.push_to_hub(MODEL_REPO, use_auth_token=True)
ethics_model.push_to_hub(MODEL_REPO, use_auth_token=True)

# 6) Push your SB3 policy ZIP up to a separate repo
API = HfApi()
POLICY_REPO = "Kelllll/ppo-ethics-agent"

# create the repo (if it doesn’t already exist)
API.create_repo(POLICY_REPO, repo_type="model", exist_ok=True)

# upload the zip
API.upload_file(
    path_or_fileobj="ppo_ethics_agent_v2.zip",
    path_in_repo="ppo_ethics_agent_v2.zip",
    repo_id=POLICY_REPO,
    token=True
)

print(" Reward model, tokenizer and PPO policy have been pushed to:")
print(f"   https://huggingface.co/{MODEL_REPO}")
print(f"   https://huggingface.co/{POLICY_REPO}")
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…
# /usr/local/lib/python3.11/dist-packages/transformers/utils/hub.py:920: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers. Please use `token` instead.
#   warnings.warn(
# README.md:   0%|          | 0.00/5.17k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/438M [00:00<?, ?B/s]
# ppo_ethics_agent_v2.zip:   0%|          | 0.00/6.95M [00:00<?, ?B/s]
#  Reward model, tokenizer and PPO policy have been pushed to:
#    https://huggingface.co/Kelllll/ethics-reward-model
#    https://huggingface.co/Kelllll/ppo-ethics-agent
